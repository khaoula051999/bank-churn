# %% [markdown]
# # Chargement et Exploration de données

# %%
#enregistrement affichage des graphe en drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#import librairies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#chargement des données/omer-Churn-Records.csv')
df=pd.read_csv('Customer-Churn-Records.csv')

# %%
df.shape
# Out:
# (3978, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3978 entries, 0 to 3977
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   RowNumber          3978 non-null   int64
#  1   CustomerId         3978 non-null   int64
#  2   CreditScore        3978 non-null   int64
#  3   Geography          3978 non-null   object
#  4   Gender             3978 non-null   object
#  5   Age                3978 non-null   int64
#  6   Tenure             3978 non-null   int64
#  7   Balance            3978 non-null   float64
#  8   NumOfProducts      3978 non-null   int64
#  9   HasCrCard          3978 non-null   bool
#  10  IsActiveMember     3978 non-null   bool
#  11  EstimatedSalary    3978 non-null   float64
#  12  Exited             3978 non-null   bool
#  13  Complain           3978 non-null   bool
#  14  SatisfactionScore  3978 non-null   int64
#  15  CardType           3978 non-null   object
#  16  PointsEarned       3978 non-null   int64
# dtypes: bool(4), float64(2), int64(8), object(3)
# memory usage: 419.7+ KB

# %% [markdown]
# <b>Description des Variables du Dataset </b>
#
# Nous pouvons observer que le dataset contient des variables catégorielles et continues. De plus, il n'y a pas de valeurs nulles.
#
# - **RowNumber** : Correspond au numéro d'enregistrement (ligne) et n'a pas d'effet sur le résultat.
# - **CustomerId** : Contient des valeurs aléatoires et n'a pas d'effet sur le départ du client.
# - **Surname** : Le nom de famille d'un client n'a pas d'impact sur sa décision de quitter la banque.
# - **CreditScore** : Peut influencer le churn des clients, car un client avec un score de crédit élevé est moins susceptible de quitter la banque.
# - **Geography** : La localisation du client peut affecter sa décision de quitter la banque.
# - **Gender** : Il est intéressant d'explorer si le genre joue un rôle dans le départ d'un client.
# - **Age** : Certainement pertinent, car les clients plus âgés sont moins susceptibles de quitter leur banque que les plus jeunes.
# - **Tenure** : Fait référence au nombre d'années pendant lesquelles le client est client de la banque. Normalement, les clients plus anciens sont plus loyaux et moins susceptibles de quitter une banque.
# - **Balance** : Un bon indicateur du churn des clients, car les personnes avec un solde plus élevé sont moins susceptibles de quitter la banque par rapport à celles avec des soldes plus bas.
# - **NumOfProducts** : Fait référence au nombre de produits qu'un client a achetés via la banque.
# - **HasCrCard** : Indique si un client possède ou non une carte de crédit. Cette colonne est également pertinente, car les personnes avec une carte de crédit sont moins susceptibles de quitter la banque.
# - **IsActiveMember** : Les clients actifs sont moins susceptibles de quitter la banque.
# - **EstimatedSalary** : Comme pour le solde, les personnes avec des salaires plus bas sont plus susceptibles de quitter la banque par rapport à celles avec des salaires plus élevés.
# - **Exited** : Indique si le client a quitté la banque ou non.
# - **Complain** : Indique si le client a fait une plainte ou non.
# - **Satisfaction Score** : Score fourni par le client pour la résolution de sa plainte.
# - **Card Type** : Type de carte détenue par le client.
# - **Points Earned** : Points gagnés par le client pour l'utilisation de la carte de crédit.

# %%
# Afficher les premières lignes
print(df.head())
# Out:
#    RowNumber  CustomerId  CreditScore Geography  Gender  Age  Tenure  \
# 0          1    15634602          619    France  Female   42       2
# 1          2    15647311          608     Spain  Female   41       1
# 2          3    15619304          502    France  Female   42       8
# 3          4    15701354          699    France  Female   39       1
# 4          5    15737888          850     Spain  Female   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1       True            True        101348.88
# 1   83807.86              1      False            True        112542.58
# 2  159660.80              3       True           False        113931.57
# 3       0.00              2      False           False         93826.63
# 4  125510.82              1       True            True         79084.10
#
#    Exited  Complain  SatisfactionScore CardType  PointsEarned
# 0    True      True                  2  DIAMOND           464
# 1   False      True                  3  DIAMOND           456
# 2    True      True                  3  DIAMOND           377
# 3   False     False                  5     GOLD           350
# 4   False     False                  5     GOLD           425

# %%
# Résumé statistique
df.describe().T
# Out:
#                     count          mean           std         min  \
# RowNumber          3978.0  2.003708e+03   1153.493444         1.0
# CustomerId         3978.0  1.569051e+07  71572.674892  15565701.0
# CreditScore        3978.0  6.499829e+02     97.265911       350.0
# Age                3978.0  3.888361e+01     10.565112        18.0
# Tenure             3978.0  5.041981e+00      2.881709         0.0
# Balance            3978.0  7.835726e+04  89717.654094         0.0
# NumOfProducts      3978.0  1.518100e+00      0.575066         1.0
# EstimatedSalary    3978.0  1.002952e+05  57785.873444         0.0
# SatisfactionScore  3978.0  3.011815e+00      1.395820         1.0
# PointsEarned       3978.0  6.053110e+02    228.087170       119.0
#
#                            25%           50%           75%          max
# RowNumber              1008.25  2.005500e+03  3.001750e+03      4000.00
# CustomerId         15628697.25  1.568960e+07  1.575226e+07  15815660.00
# CreditScore             583.00  6.520000e+02  7.170000e+02       850.00
# Age                      32.00  3.700000e+01  4.400000e+01        88.00
# Tenure                    3.00  5.000000e+00  8.000000e+00        10.00
# Balance                   0.00  9.740560e+04  1.276936e+05   4167864.40
# NumOfProducts             1.00  1.000000e+00  2.000000e+00         4.00
# EstimatedSalary       51114.12  1.005794e+05  1.490719e+05    199970.74
# SatisfactionScore         2.00  3.000000e+00  4.000000e+00         5.00
# PointsEarned            406.00  6.060000e+02  7.987500e+02      1000.00

# %%
# Vérification des valeurs manquantes
df.isnull().sum()
# Out:
# RowNumber            0
# CustomerId           0
# CreditScore          0
# Geography            0
# Gender               0
# Age                  0
# Tenure               0
# Balance              0
# NumOfProducts        0
# HasCrCard            0
# IsActiveMember       0
# EstimatedSalary      0
# Exited               0
# Complain             0
# SatisfactionScore    0
# CardType             0
# PointsEarned         0
# dtype: int64

# %% [markdown]
# La distribution des variable

# %%
# Visualisation de la distribution des variables numériques
numeric_features = df.select_dtypes(include=[np.number]).columns.tolist()
# Visualisation de la distribution des variables numériques
plt.figure(figsize=(15, 10))
for i, feature in enumerate(numeric_features):
    plt.subplot(5, 3, i + 1)
    sns.histplot(df[feature], kde=True)
    plt.title(f'Distribution de {feature}')
plt.tight_layout()
plt.show()
#plt.savefig("/content/drive/MyDrive/variableNum.png")

# %%
# Pairplot
features_of_interest = ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Exited']
sns.pairplot(df[features_of_interest], hue='Exited')
plt.show()
#pairplot.savefig("/content/drive/MyDrive/pairplot.png")

# %%
df.head()
# Out:
#    RowNumber  CustomerId  CreditScore Geography  Gender  Age  Tenure  \
# 0          1    15634602          619    France  Female   42       2
# 1          2    15647311          608     Spain  Female   41       1
# 2          3    15619304          502    France  Female   42       8
# 3          4    15701354          699    France  Female   39       1
# 4          5    15737888          850     Spain  Female   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1       True            True        101348.88
# 1   83807.86              1      False            True        112542.58
# 2  159660.80              3       True           False        113931.57
# 3       0.00              2      False           False         93826.63
# 4  125510.82              1       True            True         79084.10
#
#    Exited  Complain  SatisfactionScore CardType  PointsEarned
# 0    True      True                  2  DIAMOND           464
# 1   False      True                  3  DIAMOND           456
# 2    True      True                  3  DIAMOND           377
# 3   False     False                  5     GOLD           350
# 4   False     False                  5     GOLD           425

# %%
# #variables catégorielles
# features_of_interest = ['Geography', 'Gender', 'Tenure', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'Satisfaction Score', 'Card Type']

# # Créer des histogrammes comparatifs pour chaque caractéristique
# plt.figure(figsize=(15, 12))
# for i, feature in enumerate(features_of_interest):
#     plt.subplot(3, 3, i + 1)
#     sns.countplot(data=df, x=feature, hue='Exited')
#     plt.title(f'Variable {feature}')
#     print(df[feature].dtype)
#     print(df['Exited'].dtype)
# plt.tight_layout()
# plt.suptitle('Analysis Of Variable Exited', y=1.02)
# plt.show()
# #plt.savefig("/content/drive/MyDrive/variableCategoriale.png")
# Out:
# object
# bool
# object
# bool
# int64
# bool
# int64
# bool
# bool
# bool
# bool
# bool
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-cf9462843ab8> in <cell line: 6>()
#       6 for i, feature in enumerate(features_of_interest):
#       7     plt.subplot(3, 3, i + 1)
# ----> 8     sns.countplot(data=df, x=feature, hue='Exited')
#       9     plt.title(f'Variable {feature}')
#      10     print(df[feature].dtype)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2628         raise TypeError("Cannot pass values for both `x` and `y`.")
#    2629
# -> 2630     p = _CategoricalAggPlotter(
#    2631         data=data,
#    2632         variables=dict(x=x, y=y, hue=hue),
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in __init__(self, data, variables, order, orient, require_numeric, color, legend)
#      64     ):
#      65
# ---> 66         super().__init__(data=data, variables=variables)
#      67
#      68         # This method takes care of some bookkeeping that is necessary because the
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py in __init__(self, data, variables)
#     632         # information for numeric axes would be information about log scales.
#     633         self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634         self.assign_variables(data, variables)
#     635
#     636         # TODO Lots of tests assume that these are called to initialize the
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py in assign_variables(self, data, variables)
#     677             # to centralize / standardize data consumption logic.
#     678             self.input_format = "long"
# --> 679             plot_data = PlotData(data, variables)
#     680             frame = plot_data.frame
#     681             names = plot_data.names
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_core/data.py in __init__(self, data, variables)
#      56
#      57         data = handle_data_source(data)
# ---> 58         frame, names, ids = self._assign_variables(data, variables)
#      59
#      60         self.frame = frame
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_core/data.py in _assign_variables(self, data, variables)
#     230                 else:
#     231                     err += "An entry with this name does not appear in `data`."
# --> 232                 raise ValueError(err)
#     233
#     234             else:
#
# ValueError: Could not interpret value `Satisfaction Score` for `x`. An entry with this name does not appear in `data`.

# %%
# #variable continue
# continuous_features = ['CreditScore', 'Age', 'Balance', 'EstimatedSalary', 'Point Earned']

# # Créer des box plots comparatifs pour chaque caractéristique continue
# plt.figure(figsize=(15, 12))
# for i, feature in enumerate(continuous_features):
#     plt.subplot(3, 2, i + 1)
#     sns.boxplot(data=df, x='Exited', y=feature)
#     plt.title(f'Variable {feature}')
# plt.tight_layout()
# plt.suptitle('Analysis Of Variable Class', y=1.02)
# plt.show()

# %%
# Matrice de corrélation
# Sélectionner uniquement les colonnes numériques
numeric_df = df.select_dtypes(include=[np.number])

# Vérifier les colonnes numériques
print(numeric_df.columns)
# Matrice de corrélation pour les colonnes numériques
corr_matrix = numeric_df.corr()

# Visualisation de la matrice de corrélation
plt.figure(figsize=(10, 5))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Matrice de Corrélation')
plt.show()

#plt.savefig("/content/drive/MyDrive/correlation_matrix.png")
# Out:
# Index(['RowNumber', 'CustomerId', 'CreditScore', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'EstimatedSalary', 'SatisfactionScore',
#        'PointsEarned'],
#       dtype='object')

# %% [markdown]
# ###A Titre d'information pour interpréter une matrice de corrélation
# * Valeur de Corrélation :
# <br/>
# 	•	+1 : Corrélation positive parfaite. À mesure qu'une variable augmente, l'autre augmente proportionnellement.
#   <br/>
# •	0 : Aucune corrélation. Les variables ne montrent pas de relation linéaire.
#  <br/>
# •	-1 : Corrélation négative parfaite. À mesure qu'une variable augmente, l'autre diminue proportionnellement.
#  <br/>
# * Force de la Corrélation :
# •	0.0 à 0.19 : Très faible corrélation
#  <br/>
# •	0.2 à 0.39 : Faible corrélation
#  <br/>
# •	0.4 à 0.59 : Corrélation modérée
#  <br/>
# •	0.6 à 0.79 : Corrélation forte
#  <br/>
# •	0.8 à 1.0 : Corrélation très forte

# %% [markdown]
# # Conclusions sur l'exploration des données

# %% [markdown]
# ## Corrélations Notables
#
# 1. **Age et Exited** : Corrélation de 0.29, suggérant que l'âge est un facteur important. Les clients plus âgés sont plus susceptibles de quitter.
# 2. **Complain et Exited** : Corrélation de 0.28, indiquant que les clients ayant des plaintes sont plus susceptibles de quitter.
# 3. **Satisfaction Score et Exited** : Corrélation de -0.39, montrant que les clients moins satisfaits sont plus susceptibles de quitter.
# 4. **IsActiveMember et Exited** : Corrélation de -0.16, montrant que les membres actifs sont moins susceptibles de quitter.
#
# ## Décisions Basées sur la Corrélation
#
# ### Variables à Conserver
#
# 1. **Age** : Corrélation de 0.29 avec `Exited`.
# 2. **Complain** : Corrélation de 0.28 avec `Exited`.
# 3. **Satisfaction Score** : Corrélation de -0.39 avec `Exited`.
# 4. **IsActiveMember** : Corrélation de -0.16 avec `Exited`.
# 5. **Balance** : Corrélation de 0.12 avec `Exited`.
#
# ### Variables à Supprimer
#
# 1. **RowNumber** : Pas pertinent pour le modèle prédictif.
# 2. **CustomerId** : Identifiant unique, pas pertinent.
# 3. **Tenure** : Corrélation négligeable avec `Exited`.
# 4. **HasCrCard** : Corrélation négligeable avec `Exited`.
# 5. **EstimatedSalary** : Corrélation négligeable avec `Exited`.
